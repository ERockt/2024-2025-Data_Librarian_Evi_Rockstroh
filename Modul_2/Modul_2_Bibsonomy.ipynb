# %%
import pandas as pd

# %%
import requests
url = "https://www.bibsonomy.org/json/search/openaccess?items=1000"
result = requests.get(url)
data = result.json()

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
type(data["items"])
# Out:
# list

# %%
data["items"][5]
# Out:
# {'type': 'Bookmark',
#  'id': 'https://www.bibsonomy.org/url/4ac328b2ec5f736575fdf368fc5782c8/textundblog',
#  'tags': ['wissenschaft', 'openaccess', 'importmw'],
#  'intraHash': '4ac328b2ec5f736575fdf368fc5782c8',
#  'label': 'OpenAccess frdert die Wissenschaft!  | ZEIT ONLINE',
#  'user': 'textundblog',
#  'description': 'Im Streit um Urheberrechte & Publikationsfreiheit gert einiges durcheinander. In der Wissenschaft ist der freie Zugang zu Ergebnissen & Daten im Internet kein Schaden, sondern hchst wnsc  (tags: openaccess wissenschaft)',
#  'date': '2013-06-28 16:41:41',
#  'changeDate': '2013-06-28 16:41:41',
#  'count': 2,
#  'url': 'http://www.zeit.de/2009/16/C-digitales-Publizieren'}

# %%
df_bibsonomy = pd.DataFrame(data["items"])

# %%
df_bibsonomy
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/a55d82b9e53fc9b2...
# 1        Bookmark  https://www.bibsonomy.org/url/b83dfcc010d7e63d...
# 2        Bookmark  https://www.bibsonomy.org/url/b83dfcc010d7e63d...
# 3        Bookmark  https://www.bibsonomy.org/url/d4416dafb182c8b9...
# 4        Bookmark  https://www.bibsonomy.org/url/b83dfcc010d7e63d...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/28063eb988978...
# 1996  Publication  6413, 10.5210/ojphi.v8i1.6413, http://www.ojph...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2e7c72c09937c...
# 1998  Publication  https://www.bibsonomy.org/bibtex/2df878f9307b7...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2d84a412b7765...
#
#                                                    tags  \
# 0                  [wissenschaft, openaccess, internet]
# ...

# %%
import requests
url = "https://www.bibsonomy.org/json/search/opendata?items=1000"
treffer = requests.get(url)
daten = result.json()

# %%
daten.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
daten["items"][5]
# Out:
# {'type': 'Bookmark',
#  'id': 'https://www.bibsonomy.org/url/5de0b0055c8ae164fb970611d584270e/brightbyte',
#  'tags': ['participation', 'opendata', 'netzpolitik', 'blog'],
#  'intraHash': '5de0b0055c8ae164fb970611d584270e',
#  'label': 'Erstes Treffen des OpenData Networks : netzpolitik.org',
#  'user': 'brightbyte',
#  'description': '',
#  'date': '2009-10-30 21:33:19',
#  'changeDate': '2009-10-30 21:33:19',
#  'count': 1,
#  'url': 'http://www.netzpolitik.org/2009/erstes-treffen-des-opendata-networks/'}

# %%
df_open = pd.DataFrame(daten["items"])

# %%
df_open
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/8385fbc1465b19c8...
# 1        Bookmark  https://www.bibsonomy.org/url/8385fbc1465b19c8...
# 2        Bookmark  https://www.bibsonomy.org/url/df5e89e1f0f7ed26...
# 3        Bookmark  https://www.bibsonomy.org/url/06cd40fbf81c158d...
# 4        Bookmark  https://www.bibsonomy.org/url/8385fbc1465b19c8...
# ...           ...                                                ...
# 997   Publication  https://www.bibsonomy.org/bibtex/2a167717c62cc...
# 998   Publication  https://www.bibsonomy.org/bibtex/2de67ce2cf566...
# 999   Publication  https://www.bibsonomy.org/bibtex/2f0b4c3780a10...
# 1000  Publication  https://www.bibsonomy.org/bibtex/2cf16ec8faa98...
# 1001  Publication  https://www.bibsonomy.org/bibtex/2dbc54ceb8cd2...
#
#                                                    tags  \
# 0                           [opendata, germany, verein]
# ...
